# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## The first thing to do is to make the data file public on google and retrieve the link.
#
# The link of the newly cleaned data is the following:
#
# https://drive.google.com/file/d/1fFRRFVAldtG-xzSQJaL1i-WPZalRpHvM/view?usp=sharing
#
# the part of the link that you want to copy is the mixed letters after `/d/` and before `/view?`
#
# **1fFRRFVAldtG-xzSQJaL1i-WPZalRpHvM**
#
# ---
#
#
# <br>
#
# you use gdown in the following format
#
# !gdown --id id_copy_from_above -O name_of_file.file_extension
#
#
# the --id is the id of the public file on Google drive <br>
# the -O is the upper case letter o
# the name of file could be any name you want to five the file

# %%
# !gdown --id 1fFRRFVAldtG-xzSQJaL1i-WPZalRpHvM -O cleanedYelpVectorized.csv
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1fFRRFVAldtG-xzSQJaL1i-WPZalRpHvM
# To: /content/cleanedYelpVectorized.csv
# 100% 1.11G/1.11G [00:09<00:00, 111MB/s]

# %%
#Now you simply read the csv file as normal using pandas, write the csv name as string as it is save as a path to the file locally

df = pd.read_csv("cleanedYelpVectorized.csv")

# %%
df.head()
# Out:
#    index             business_id  stars  \
# 0      0  EQ-TZ2eeD_E0BHuvoaeG5Q      4
# 1      1  S2Ho8yLxhKAa26pBAm6rxA      3
# 2      2  ltBBYdNzkeKdCNPDAsxwAA      2
# 3      3  Zx7n8mdt8OzLRXVzolXNhQ      5
# 4      4  W4ZEKkva9HpAdZG88juwyQ      3
#
#                                                 text  \
# 0  Locals recommended Milktooth, and it's an amaz...
# 1  Service was crappy, and food was mediocre.  I ...
# 2  I at least have to give this restaurant two st...
# 3  Amazing biscuits and (fill in the blank). Grea...
# 4  In a word... "OVERRATED!".  The food took fore...
#
#                                              cleaned  \
# 0  locals recommended milktooth and it is an amaz...
# 1  service was crappy and food was mediocre i wis...
# 2  i at least have to give this restaurant two st...
# 3  amazing biscuits and fill in the blank great c...
# 4  in a word overrated the food took forever to c...
#
#                                        spell_checked  \
# ...
